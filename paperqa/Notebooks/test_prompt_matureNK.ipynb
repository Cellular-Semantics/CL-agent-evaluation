# %%
! poetry run aurelian paperqa index -d papers/papers_matureNKcell/
# Out:
# 2025-07-14 13:06:03,199 - paperqa.agents.search - INFO - New file to index: Cytometry Pt A - 2019 - Mousset - Comprehensive Phenotyping of T Cells Using Flow Cytometry.pdf...
# 2025-07-14 13:06:03,228 - paperqa.agents.search - INFO - New file to index: IMCB-97-586.pdf...
# Logfire project URL: ]8;id=444497;https://logfire-eu.pydantic.dev/caroline-99/aurelian\https://logfire-eu.pydantic.dev/caroline-99/aurelian]8;;\
# 13:06:03 - LiteLLM Router:INFO: router.py:660 - Routing strategy: simple-shuffle
# 2025-07-14 13:06:03,551 - LiteLLM Router - INFO - Routing strategy: simple-shuffle
# 13:06:03 - LiteLLM:INFO: utils.py:3120 -
# LiteLLM completion() model= gpt-4.1-2025-04-14; provider = openai
# 2025-07-14 13:06:03,569 - LiteLLM - INFO -
# LiteLLM completion() model= gpt-4.1-2025-04-14; provider = openai
# 13:06:03 - LiteLLM Router:INFO: router.py:660 - Routing strategy: simple-shuffle
# 2025-07-14 13:06:03,669 - LiteLLM Router - INFO - Routing strategy: simple-shuffle
# ...

# %% [markdown]
# ## Updated prompt

# %%
import subprocess
import shlex

# Define your prompt as a clean Python string
prompt_text = """
For the following text, first break down the definition into individual, atomic assertions. Each assertion should be a single, verifiable statement. After extracting the assertions, create a table with the following columns:

- **Assertion**: A single, verifiable statement about the cell type.
- **Validated**: A strict "True" or "False" value. This column should only contain "True" if the entire assertion is stated and supported by the provided literature. If the literature contradicts the assertion, or is not supported, the value must be "False".
- **Evidence**: A brief summary of the evidence from the literature that supports the "Validated" column's value.
- **References**: The sources from the literature that were used for validation.

Text:
name: mature NK T cell, human
def: "A mature NK T cell that can be identified by the expression of CD56 in humans."
is_a: CL:0000814 ! mature NK T cell
"""

# Construct the command as a list of arguments
command = [
    "aurelian",
    "paperqa",
    "ask",
    prompt_text,
    "-d",
    "papers/papers_matureNKcell/"
]

# Run the command
# Using capture_output=True to see the results in the notebook
result = subprocess.run(command, capture_output=True, text=True)

# Print the standard output and any errors
print("STDOUT:")
print(result.stdout)

print("\nSTDERR:")
print(result.stderr)
# Out:
# STDOUT:
# ...

# %% [markdown]
# ### Mature NKT cell Assertions Table
#
# | **Assertion** | **Validated** | **Evidence** | **References** |
# |---|:---:|---|---|
# | 1. Mature human NKT cells can be identified by the expression of CD56. | False | Most mature human NKT cells express CD56, but CD56 is not exclusive or definitive for NKT cells; it is also expressed on NK cells and some T cell subsets. The literature emphasizes that while CD56 is commonly found on mature NKT cells, it is not a specific or exclusive marker for their identification. | liu2019theperipheraldifferentiation pages 2–2 |
# | 2. Mature human NKT cells commonly express CD56. | True | A significant proportion of mature human NKT cells express CD56: 42.1% ± 16.3% of CD4+, 75.4% ± 18.2% of CD8+, and 79.1% ± 12.7% of DN NKT cells. This is in contrast to conventional T cells, where CD56 expression is rare. | liu2019theperipheraldifferentiation pages 5–6 |
# | 3. CD56 expression is a definitive marker for mature human NKT cells. | False | CD56 is not a definitive or exclusive marker for mature human NKT cells, as it is also expressed on NK cells and some T cell subsets. The literature specifically notes that CD56 should not be considered a specific identifier for mature NKT cells. | liu2019theperipheraldifferentiation pages 2–2 |
# | 4. The cell type is a mature NK T cell (is_a: CL:0000814). | True | The literature discusses mature human NKT cells, including their phenotypic and functional characteristics, supporting the classification as mature NK T cells. | liu2019theperipheraldifferentiation pages 1–2, 2–2 |
#
# ### Summary
#
# Mature human natural killer T (NKT) cells are a subset of CD1d-restricted lymphocytes with a semi-invariant T-cell receptor repertoire and a predominant memory phenotype (liu2019theperipheraldifferentiation pages 1-2, 2-2). While a significant proportion of mature human NKT cells express CD56—ranging from approximately 42% in CD4+ NKT cells to over 75% in CD8+ and double negative (DN) NKT cells—CD56 expression is not exclusive to NKT cells and is also found on NK cells and some T cell subsets (liu2019theperipheraldifferentiation pages 5-6, 2-2). Therefore, although CD56 is commonly expressed on mature human NKT cells, it should not be used as a definitive or exclusive marker for their identification (liu2019theperipheraldifferentiation pages 2-2). The cell type described is appropriately classified as a mature NK T cell (CL:0000814), but the definition should not rely solely on CD56 expression for identification.
#
# References: 1. (liu2019theperipheraldifferentiation pages 5-6): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
#
# 2. (liu2019theperipheraldifferentiation pages 1-2): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
#
# 3. (liu2019theperipheraldifferentiation pages 2-2): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.

# %% [markdown]
# ## David's original prompt

# %%
! aurelian paperqa ask 'Please break down the following text into a set of independent assertions. Test the validity of each assertion against the literature provided. Return the results as a table with columns for assertion, summary text, validated (True/False) and references. Text: name: mature NK T cell, human; def: "A mature NK T cell that can be identified by the expression of CD56 in humans." ;is_a: CL:0000814 ! mature NK T cell' -d papers/papers_matureNKcell/
# Out:
# 2025-07-14 13:14:39,302 - paperqa.agents.main - INFO - Beginning agent 'ToolSelector' run with question 'Please break down the following text into a set of independent assertions. Test the validity of each assertion against the literature provided. Return the results as a table with columns for assertion, summary text, validated (True/False) and references. Text: name: mature NK T cell, human; def: "A mature NK T cell that can be identified by the expression of CD56 in humans." ;is_a: CL:0000814 ! mature NK T cell' and full settings {'llm': 'gpt-4.1-2025-04-14', 'llm_config': None, 'summary_llm': 'gpt-4.1-2025-04-14', 'summary_llm_config': None, 'embedding': 'text-embedding-3-small', 'embedding_config': None, 'temperature': 0.1, 'batch_size': 1, 'texts_index_mmr_lambda': 1.0, 'verbosity': 0, 'answer': {'evidence_k': 10, 'evidence_detailed_citations': True, 'evidence_retrieval': True, 'evidence_summary_length': 'about 100 words', 'evidence_skip_summary': False, 'answer_max_sources': 5
# ...

# %% [markdown]
# ### Answer: Atomic Assertions Table
#
# | **Assertion** | **Summary Text** | **Validated (True/False)** | **References** |
# |---|---|:---:|---|
# | 1. A mature NK T cell, human, is a mature NK T cell. | The term refers to a mature natural killer T (NKT) cell in humans. | True | liu2019theperipheraldifferentiation pages 1–2, 2–2, 4–5 |
# | 2. A mature NK T cell, human, can be identified by the expression of CD56. | The definition states that mature human NKT cells can be identified by CD56 expression. | False | liu2019theperipheraldifferentiation pages 2–3, 3–4 |
#
# The term "mature NK T cell, human" refers to a mature natural killer T (NKT) cell in humans, which is a subset of lymphocytes with features of both NK cells and T cells. This classification is supported by the literature, which describes the differentiation and maturation of human NKT cells and their relationship to the broader class of mature NKT cells (liu2019theperipheraldifferentiation pages 1-2, liu2019theperipheraldifferentiation pages 2-2, liu2019theperipheraldifferentiation pages 4-5).
#
# However, the assertion that mature human NKT cells can be identified by the expression of CD56 is not fully supported. While CD56 is expressed at much higher frequencies on NKT cells compared to conventional T cells, it is not universally expressed on all mature NKT cells. Data indicate that approximately 62.8% of NKT cells express CD56, meaning a significant proportion do not. Therefore, CD56 is a prominent but not definitive marker for mature human NKT cells (liu2019theperipheraldifferentiation pages 2-3, liu2019theperipheraldifferentiation pages 3-4).
#
# References: 1. (liu2019theperipheraldifferentiation pages 1-2): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
#
# 2. (liu2019theperipheraldifferentiation pages 2-2): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
#
# 3. (liu2019theperipheraldifferentiation pages 2-3): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
#
# 4. (liu2019theperipheraldifferentiation pages 3-4): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
#
# 5. (liu2019theperipheraldifferentiation pages 4-5): Jie Liu, Brenna J Hill, Sam Darko, Kaimei Song, Máire F Quigley, Tedi E Asher, Yohei Morita, Hui Y Greenaway, Vanessa Venturi, Daniel C Douek, Miles P Davenport, David A Price, and Mario Roederer. The peripheral differentiation of human natural killer t cells. Immunology and Cell Biology, 97:586-596, Apr 2019. URL: https://doi.org/10.1111/imcb.12248, doi:10.1111/imcb.12248. This article has 25 citations and is from a peer-reviewed journal.
