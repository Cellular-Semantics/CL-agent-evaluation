# %%
! poetry run aurelian paperqa index -d papers/papers_onychofibroblast/
# Out:
# 2025-07-14 10:22:43,189 - paperqa.agents.search - INFO - New file to index: 42003_2021_Article_2223.pdf...
# 2025-07-14 10:22:43,251 - paperqa.agents.search - INFO - New file to index: J Cutan Pathol - 2024 - Shim - The concept of onychodermis containing onychofibroblasts has histological  microanatomical  -2.pdf...
# 2025-07-14 10:22:43,392 - paperqa.agents.search - INFO - New file to index: 1-s2.0-S0022202X2201675X-main.pdf...
# Logfire project URL: ]8;id=930616;https://logfire-eu.pydantic.dev/caroline-99/aurelian\https://logfire-eu.pydantic.dev/caroline-99/aurelian]8;;\
# 10:22:43 - LiteLLM Router:INFO: router.py:660 - Routing strategy: simple-shuffle
# 2025-07-14 10:22:43,761 - LiteLLM Router - INFO - Routing strategy: simple-shuffle
# 10:22:43 - LiteLLM Router:INFO: router.py:660 - Routing strategy: simple-shuffle
# 2025-07-14 10:22:43,782 - LiteLLM Router - INFO - Routing strategy: simple-shuffle
# 10:22:43 - LiteLLM:INFO: utils.py:3120 -
# ...

# %% [markdown]
# ## David's original prompt

# %%
! Aurelian paperqa ask 'Please break down the following text into a set of independent assertions. Test the validity of each assertion against the literature provided. Return the results as a table with columns for assertion, summary text, validated (True/False) and references. Text: name: onychofibroblast; def: "A specialised fibroblast located in the onychodermis that plays a key role in nail growth and regeneration by interacting with LGR6-positive nail matrix keratinocytes. These interactions mediate essential signalling pathways, particularly WNT signalling, which is critical for epithelial–mesenchymal communication and coordinated nail development. In humans, this cell expresses key markers, including RSPO4, MSX1, WIF1, and BMP5, all involved in nail differentiation." ;is_a: CL:0000057 ! fibroblast; part_of: UBERON:0002067 ! dermis;' -d papers/papers_onychofibroblast/
# Out:
# 2025-07-14 10:23:41,431 - paperqa.agents.main - INFO - Beginning agent 'ToolSelector' run with question 'Please break down the following text into a set of independent assertions. Test the validity of each assertion against the literature provided. Return the results as a table with columns for assertion, summary text, validated (True/False) and references. Text: name: onychofibroblast; def: "A specialised fibroblast located in the onychodermis that plays a key role in nail growth and regeneration by interacting with LGR6-positive nail matrix keratinocytes. These interactions mediate essential signalling pathways, particularly WNT signalling, which is critical for epithelial–mesenchymal communication and coordinated nail development. In humans, this cell expresses key markers, including RSPO4, MSX1, WIF1, and BMP5, all involved in nail differentiation." ;is_a: CL:0000057 ! fibroblast; part_of: UBERON:0002067 ! dermis;' and full settings {'llm': 'gpt-4.1-2025-04-14', 'llm_config': Non
# ...

# %% [markdown]
# ### Onychofibroblast Validation Table
#
# | **Assertion** | **Summary Text** | **Validated (True/False)** | **References** |
# |---|---|:---:|---|
# | Onychofibroblast is a specialised fibroblast located in the onychodermis. | Onychofibroblasts are a distinct population of fibroblasts located in the connective tissue beneath the nail matrix (onychodermis). | True | kim2021singlecellrnasequencing pages 4-5, 5-5 |
# | Onychofibroblasts play a key role in nail growth and regeneration by interacting with LGR6-positive nail matrix keratinocytes. | Onychofibroblasts interact with LGR6-positive keratinocytes, facilitating WNT/β-catenin activation important for nail growth. | True | kim2021singlecellrnasequencing pages 1-2, 5-5 |
# | These interactions mediate essential signalling pathways, particularly WNT signalling, critical for epithelial–mesenchymal communication and coordinated nail development. | RSPO4+ onychofibroblasts and LGR6+ keratinocytes mediate WNT signaling, essential for epithelial–mesenchymal communication and nail development. | True | kim2021singlecellrnasequencing pages 1-2, 5-5 |
# | In humans, onychofibroblasts express key markers, including RSPO4, MSX1, WIF1, and BMP5, all involved in nail differentiation. | Onychofibroblasts are characterized by high expression of RSPO4, MSX1, WIF1, and BMP5, implicated in nail differentiation. | True | kim2021singlecellrnasequencing pages 1-2, 4-5 |
# | Onychofibroblast is_a fibroblast (CL:0000057). | Onychofibroblasts are a distinct population of mesenchymal (fibroblast) cells. | True | kim2021singlecellrnasequencing pages 1-2 |
# | Onychofibroblast is part_of dermis (UBERON:0002067). | Onychofibroblasts are located in the nail-specific dermis beneath the nail matrix. | True | kim2021singlecellrnasequencing pages 5-5 |
#
#
# **Summary:**
# All assertions in the provided definition of onychofibroblast are validated by the referenced literature. Onychofibroblasts are a specialized fibroblast population within the onychodermis, defined by high expression of RSPO4, MSX1, WIF1, and BMP5. They are situated beneath the nail matrix and interact with LGR6-positive keratinocytes, mediating WNT signaling crucial for epithelial–mesenchymal communication, nail growth, and regeneration. These cells are considered part of the nail-specific dermis and are classified as fibroblasts (CL:0000057) (kim2021singlecellrnasequencing pages 1-2, kim2021singlecellrnasequencing pages 4-5, kim2021singlecellrnasequencing pages 5-5).
#
# **References:**
# References: 1. (kim2021singlecellrnasequencing pages 1-2): Hyun Je Kim, Joon Ho Shim, Ji-Hye Park, Hyun Tae Shin, Jong Sup Shim, Kee-Taek Jang, Woong-Yang Park, Kyung-Hoon Lee, Eun Ji Kwon, Hyung-Suk Jang, Hanseul Yang, Jong Hee Lee, Jun-Mo Yang, and Dongyoun Lee. Single-cell rna sequencing of human nail unit defines rspo4 onychofibroblasts and spink6 nail epithelium. Communications Biology, Jun 2021. URL: https://doi.org/10.1038/s42003-021-02223-w, doi:10.1038/s42003-021-02223-w. This article has 17 citations and is from a peer-reviewed journal.
#
# 2. (kim2021singlecellrnasequencing pages 4-5): Hyun Je Kim, Joon Ho Shim, Ji-Hye Park, Hyun Tae Shin, Jong Sup Shim, Kee-Taek Jang, Woong-Yang Park, Kyung-Hoon Lee, Eun Ji Kwon, Hyung-Suk Jang, Hanseul Yang, Jong Hee Lee, Jun-Mo Yang, and Dongyoun Lee. Single-cell rna sequencing of human nail unit defines rspo4 onychofibroblasts and spink6 nail epithelium. Communications Biology, Jun 2021. URL: https://doi.org/10.1038/s42003-021-02223-w, doi:10.1038/s42003-021-02223-w. This article has 17 citations and is from a peer-reviewed journal.
#
# 3. (kim2021singlecellrnasequencing pages 5-5): Hyun Je Kim, Joon Ho Shim, Ji-Hye Park, Hyun Tae Shin, Jong Sup Shim, Kee-Taek Jang, Woong-Yang Park, Kyung-Hoon Lee, Eun Ji Kwon, Hyung-Suk Jang, Hanseul Yang, Jong Hee Lee, Jun-Mo Yang, and Dongyoun Lee. Single-cell rna sequencing of human nail unit defines rspo4 onychofibroblasts and spink6 nail epithelium. Communications Biology, Jun 2021. URL: https://doi.org/10.1038/s42003-021-02223-w, doi:10.1038/s42003-021-02223-w. This article has 17 citations and is from a peer-reviewed journal.

# %% [markdown]
# ## Updated prompt

# %%
import subprocess
import shlex

# Define your prompt as a clean Python string
prompt_text = """
For the following text, first break down the definition into individual, atomic assertions. Each assertion should be a single, verifiable statement. After extracting the assertions, create a table with the following columns:

- **Assertion**: A single, verifiable statement about the cell type.
- **Validated**: A strict "True" or "False" value. This column should only contain "True" if the entire assertion is stated and supported by the provided literature. If the literature contradicts the assertion, or is not supported, the value must be "False".
- **Evidence**: A brief summary of the evidence from the literature that supports the "Validated" column's value.
- **References**: The sources from the literature that were used for validation.

Text:
name: onychofibroblast
def: "A specialised fibroblast located in the onychodermis that plays a key role in nail growth and regeneration by interacting with LGR6-positive nail matrix keratinocytes. These interactions mediate essential signalling pathways, particularly WNT signalling, which is critical for epithelial–mesenchymal communication and coordinated nail development. In humans, this cell expresses key markers, including RSPO4, MSX1, WIF1, and BMP5, all involved in nail differentiation."
is_a: CL:0000057 ! fibroblast
part_of: UBERON:0002067 ! dermis
"""

# Construct the command as a list of arguments
command = [
    "aurelian",
    "paperqa",
    "ask",
    prompt_text,
    "-d",
    "papers/papers_onychofibroblast"
]

# Run the command
# Using capture_output=True to see the results in the notebook
result = subprocess.run(command, capture_output=True, text=True)

# Print the standard output and any errors
print("STDOUT:")
print(result.stdout)

print("\nSTDERR:")
print(result.stderr)
# Out:
# STDOUT:
# ...

# %% [markdown]
# ### Onychofibroblast Validation Table
#
# | **Assertion** | **Validated** | **Evidence** | **References** |
# |---|:---:|---|---|
# | Onychofibroblasts are specialised fibroblasts. | True | Single-cell RNA sequencing identified onychofibroblasts as a distinct fibroblast population in the human nail unit. | kim2021singlecellrnasequencing pages 4–4 |
# | Onychofibroblasts are located in the onychodermis. | True | Onychofibroblasts are described as residing in the connective tissue (onychodermis) beneath the nail matrix. | kim2021singlecellrnasequencing pages 5–5 |
# | Onychofibroblasts play a key role in nail growth and regeneration. | True | The spatial relationship and signaling interactions with LGR6+ nail matrix cells mediate WNT/β-catenin activation, which is important for nail growth and regeneration. | kim2021singlecellrnasequencing pages 1–2 |
# | Onychofibroblasts interact with LGR6-positive nail matrix keratinocytes. | True | Network analysis and spatial localization show RSPO4+ onychofibroblasts in proximity to LGR6+ nail matrix keratinocytes, supporting direct interaction. | kim2021singlecellrnasequencing pages 5–5 |
# | These interactions mediate essential signalling pathways, particularly WNT signalling. | True | Ligand-target analysis and immunohistochemistry demonstrate RSPO4–LEF1 signaling and WNT/β-catenin pathway activation in nail matrix keratinocytes. | kim2021singlecellrnasequencing pages 5–6 |
# | WNT signalling is critical for epithelial–mesenchymal communication and coordinated nail development. | True | WNT/β-catenin activation is shown to be essential for nail growth and regeneration, indicating its role in epithelial–mesenchymal communication. | kim2021singlecellrnasequencing pages 1–2 |
# | In humans, onychofibroblasts express RSPO4, MSX1, WIF1, and BMP5. | True | Single-cell RNA sequencing, in situ hybridization, and immunohistochemistry confirm expression of RSPO4, MSX1, WIF1, and BMP5 in onychofibroblasts. | kim2021singlecellrnasequencing pages 4–5 |
# | RSPO4, MSX1, WIF1, and BMP5 are involved in nail differentiation. | True | These genes are associated with WNT signaling and nail differentiation processes, as indicated by their expression in onychofibroblasts and functional annotation. | kim2021singlecellrnasequencing pages 1–2 |
# | Onychofibroblasts are a subclass of fibroblasts (CL:0000057). | True | Onychofibroblasts are defined as a distinct fibroblast population by single-cell RNA sequencing. | kim2021singlecellrnasequencing pages 4–4 |
# | Onychofibroblasts are part of the dermis (UBERON:0002067). | True | Onychofibroblasts are located in the connective tissue (onychodermis) beneath the nail matrix, which is part of the dermis. | kim2021singlecellrnasequencing pages 5–5 |
#
# ---
#
# Onychofibroblasts are a specialized fibroblast population located in the onychodermis, the connective tissue beneath the human nail matrix. Single-cell RNA sequencing and spatial transcriptomics have identified these cells as expressing key markers, including RSPO4, MSX1, WIF1, and BMP5, all of which are implicated in nail differentiation and WNT signaling. Onychofibroblasts are situated in close proximity to LGR6-positive nail matrix keratinocytes, and network analyses predict significant epithelial–mesenchymal interactions between these cell types. These interactions are mediated by RSPO4–LEF1 signaling, leading to activation of the WNT/β-catenin pathway, which is critical for nail growth, regeneration, and coordinated epithelial–mesenchymal communication. Immunohistochemistry and in situ hybridization confirm the expression of these markers in onychofibroblasts, and functional studies demonstrate that RSPO4 from onychofibroblasts upregulates WNT signaling genes in nail matrix keratinocytes. Thus, onychofibroblasts play a central role in the regulation of nail unit homeostasis and regeneration through WNT-mediated signaling (kim2021singlecellrnasequencing pages 1-2, kim2021singlecellrnasequencing pages 4-4, kim2021singlecellrnasequencing pages 4-5, kim2021singlecellrnasequencing pages 5-5, kim2021singlecellrnasequencing pages 5-6).
#
